# %% [markdown]
# # Secondary v2 model evaluation
#
# This notebook compares the original secondary layer against a phase/O2-gated v2 layer while keeping the calibrated core fermentation model fixed.

# %%
from pathlib import Path
import pandas as pd
from IPython.display import Image, display

ROOT = Path.cwd()
if not (ROOT / 'results').exists() and (ROOT / 'fermentation_model').exists():
    ROOT = ROOT / 'fermentation_model'
RESULTS = ROOT / 'results/secondary_v2_model_evaluation'
display(pd.read_csv(RESULTS / 'fit_comparison.csv'))
display(pd.read_csv(RESULTS / 'state_fit_metrics.csv'))
display(pd.read_csv(RESULTS / 'v2_reduced_o2fixed_estimability.csv'))
# Out:
#                           model  success  status  \
# 0          secondary_v1_current     True     NaN
# 1     secondary_v2_phase_o2free     True     2.0
# 2    secondary_v2_phase_o2fixed     True     2.0
# 3  secondary_v2_reduced_o2fixed     True     2.0
#
#                                       message  nfev  initial_wsse  \
# 0     loaded from current secondary_joint fit   NaN           NaN
# 1  `ftol` termination condition is satisfied.  16.0  10286.210021
# 2  `ftol` termination condition is satisfied.  12.0  10286.210021
# 3  `ftol` termination condition is satisfied.   8.0  16950.376379
#
#     final_wsse  n_residuals  wsse_per_residual
# 0  8706.956253          588          14.807749
# 1  5400.341992          592           9.122199
# 2  5756.227087          590           9.756317
# 3  5756.427666          589           9.773222
#                            model    state  n_obs         wsse  wsse_per_obs  \
# 0           secondary_v1_current      Pyr    313  3065.923934      9.795284
# 1           secondary_v1_current    AcAld    193  4855.454778     25.157797
# 2           secondary_v1_current  Acetate     50   687.448168     13.748963
# 3           secondary_v1_current       O2     32    98.129373      3.066543
# 4      secondary_v2_phase_o2free      Pyr    313  1861.100936      5.946009
# 5      secondary_v2_phase_o2free    AcAld    193  2644.434013     13.701731
# 6      secondary_v2_phase_o2free  Acetate     50   673.245330     13.464907
# 7      secondary_v2_phase_o2free       O2     32   188.850723      5.901585
# 8     secondary_v2_phase_o2fixed      Pyr    313  2292.756082      7.325099
# 9     secondary_v2_phase_o2fixed    AcAld    193  2685.565449     13.914847
# 10    secondary_v2_phase_o2fixed  Acetate     50   677.581243     13.551625
# 11    secondary_v2_phase_o2fixed       O2     32    98.129373      3.066543
# 12  secondary_v2_reduced_o2fixed      Pyr    313  2291.954845      7.322539
# 13  secondary_v2_reduced_o2fixed    AcAld    193  2686.893739     13.921729
# 14  secondary_v2_reduced_o2fixed  Acetate     50   677.116367     13.542327
# 15  secondary_v2_reduced_o2fixed       O2     32    98.129373      3.066543
#
#          rmse        mae  obs_median  obs_range
# 0   18.778451  14.747583      35.000      98.00
# 1   40.126039  32.098977     177.000     288.00
# 2    0.129779   0.105739       0.300       0.39
# 3    0.350231   0.297618       0.615       1.35
# 4   14.630664  11.136391      35.000      98.00
# 5   29.612679  23.543454     177.000     288.00
# 6    0.128431   0.104563       0.300       0.39
# 7    0.485864   0.423880       0.615       1.35
# 8   16.238952  12.125478      35.000      98.00
# 9   29.842088  23.598691     177.000     288.00
# 10   0.128844   0.105026       0.300       0.39
# 11   0.350231   0.297618       0.615       1.35
# 12  16.236115  12.128513      35.000      98.00
# 13  29.849467  23.615169     177.000     288.00
# 14   0.128800   0.104960       0.300       0.39
# 15   0.350231   0.297618       0.615       1.35
#    parameter     theta  std_log_approx  approx_95_multiplier  active_bound  \
# 0    kPyrS_N  0.850862        0.037979              1.077280         False
# 1     kPyrO2  0.273189        0.100643              1.218061         False
# 2  kPyrDrain  0.003591        0.060402              1.125680         False
# 3    kAldS_N  2.359888        0.013137              1.026082         False
# 4    kAldRed  0.000010        5.071655          20752.958471         False
# 5     kAcAld  0.001392        0.049394              1.101653         False
# 6  kAcStress  0.002616        0.031653              1.064004         False
#
#        classification
# 0      well_estimated
# 1      well_estimated
# 2      well_estimated
# 3      well_estimated
# 4  weak_or_confounded
# 5      well_estimated
# 6      well_estimated

# %% [markdown]
# ## Weak FIM directions

# %%
display(pd.read_csv(RESULTS / 'v2_reduced_o2fixed_eigen_spectrum.csv').head(8))
display(pd.read_csv(RESULTS / 'v2_reduced_o2fixed_weak_loadings.csv'))
# Out:
#    direction    eigenvalue  relative_eigenvalue
# 0          1      0.038872             0.000003
# 1          2     70.398782             0.005315
# 2          3    836.831980             0.063184
# 3          4   1011.037312             0.076337
# 4          5   1156.315074             0.087306
# 5          6   6654.920826             0.502470
# 6          7  13244.413063             1.000000
#    weak_direction   eigenvalue  \
# 0               1     0.038872
# 1               2    70.398782
# 2               3   836.831980
# 3               4  1011.037312
# 4               5  1156.315074
# 5               6  6654.920826
#
#                                  dominant_parameters  \
# 0  kAldRed, kAcAld, kAcStress, kAldS_N, kPyrO2, k...
# 1  kPyrO2, kPyrDrain, kPyrS_N, kAcAld, kAldS_N, k...
# 2  kAcAld, kAldS_N, kAcStress, kAldRed, kPyrDrain...
# 3  kAcStress, kAcAld, kAldS_N, kAldRed, kPyrS_N, ...
# 4  kPyrS_N, kPyrDrain, kPyrO2, kAcAld, kAcStress,...
# 5  kPyrDrain, kPyrO2, kPyrS_N, kAldS_N, kAcAld, k...
#
#                       dominant_abs_loadings
# 0  1.000, 0.007, 0.000, 0.000, 0.000, 0.000
# 1  0.842, 0.482, 0.240, 0.000, 0.000, 0.000
# 2  0.929, 0.287, 0.234, 0.007, 0.001, 0.001
# 3  0.972, 0.225, 0.067, 0.001, 0.000, 0.000
# 4  0.822, 0.563, 0.088, 0.001, 0.000, 0.000
# 5  0.671, 0.532, 0.517, 0.001, 0.000, 0.000

# %% [markdown]
# ## Fit comparison plots

# %%
for png in sorted((RESULTS / 'plots').glob('secondary_v2_fit_*.png')):
    print(png.name)
    display(Image(filename=str(png)))
# Out:
# secondary_v2_fit_historical_vl3_25026.png
# secondary_v2_fit_historical_vl3_25027.png
# secondary_v2_fit_historical_vl3_25085.png
# secondary_v2_fit_historical_vl3_25086.png
# secondary_v2_fit_historical_vl3_25150.png
# secondary_v2_fit_historical_vl3_25151.png
# secondary_v2_fit_historical_vl3_25170.png
# secondary_v2_fit_historical_vl3_25171.png
# secondary_v2_fit_natural_LAB004.png
# secondary_v2_fit_natural_LAB005.png
# secondary_v2_fit_natural_LAB006.png
# secondary_v2_fit_natural_LAB007.png
# secondary_v2_fit_natural_LAB008.png
# secondary_v2_fit_natural_LAB009.png
# secondary_v2_fit_natural_LAB010.png
# secondary_v2_fit_natural_LAB011.png
# secondary_v2_fit_natural_LAB012.png
# secondary_v2_fit_synthetic_MS007.png
# secondary_v2_fit_synthetic_MS008.png
# secondary_v2_fit_synthetic_MS009.png
# secondary_v2_fit_synthetic_MS010.png
# secondary_v2_fit_synthetic_MS011.png
# secondary_v2_fit_synthetic_MS012.png
# secondary_v2_fit_synthetic_MS013.png
# secondary_v2_fit_synthetic_MS014.png
# secondary_v2_fit_synthetic_MS015.png
# secondary_v2_fit_synthetic_MS016.png

# %% [markdown]
# ## Report

# %%
print((RESULTS / 'secondary_v2_model_report.md').read_text(encoding='utf-8'))
# Out:
# # Secondary v2 model evaluation
#
# ## Purpose
#
# This run tests whether the poor current fits for pyruvate, acetaldehyde, acetate, and DO are mainly due to the secondary-state structure. The core fermentation simulation is kept fixed and only the secondary layer is changed.
#
# ## v2 structure
#
# The v2 layer adds nitrogen-phase and oxygen gates to the apparent production and drainage terms:
#
# $$h_N=\frac{N}{N+K_N},\qquad h_{stat}=1-h_N,$$
#
# $$g_{O_2}=\frac{O_2}{O_2+K_{O_2}},\qquad h_{ana}=\frac{K_{O_2}}{O_2+K_{O_2}}.$$
#
# Pyruvate production is split between N-rich and stationary phases plus an early oxygen-linked source. Acetaldehyde production is split similarly and includes pyruvate and oxygen-linked contributions. Acetate keeps the acetaldehyde oxidation, stress, and assimilation terms. DO keeps passive transfer plus cellular consumption.
#
# ## Fit summary
#
# | model                        | success   |   status | message                                    |   nfev |   initial_wsse |   final_wsse |   n_residuals |   wsse_per_residual |
# |:-----------------------------|:----------|---------:|:-------------------------------------------|-------:|---------------:|-------------:|--------------:|--------------------:|
# | secondary_v1_current         | True      |      nan | loaded from current secondary_joint fit    |    nan |          nan   |      8706.96 |           588 |            14.8077  |
# | secondary_v2_phase_o2free    | True      |        2 | `ftol` termination condition is satisfied. |     16 |        10286.2 |      5400.34 |           592 |             9.1222  |
# | secondary_v2_phase_o2fixed   | True      |        2 | `ftol` termination condition is satisfied. |     12 |        10286.2 |      5756.23 |           590 |             9.75632 |
# | secondary_v2_reduced_o2fixed | True      |        2 | `ftol` termination condition is satisfied. |      8 |        16950.4 |      5756.43 |           589 |             9.77322 |
#
# ## Per-state comparison
#
# | model                        | state   |   n_obs |      wsse |   wsse_per_obs |      rmse |       mae |   obs_median |   obs_range |
# |:-----------------------------|:--------|--------:|----------:|---------------:|----------:|----------:|-------------:|------------:|
# | secondary_v1_current         | Pyr     |     313 | 3065.92   |        9.79528 | 18.7785   | 14.7476   |       35     |       98    |
# | secondary_v1_current         | AcAld   |     193 | 4855.45   |       25.1578  | 40.126    | 32.099    |      177     |      288    |
# | secondary_v1_current         | Acetate |      50 |  687.448  |       13.749   |  0.129779 |  0.105739 |        0.3   |        0.39 |
# | secondary_v1_current         | O2      |      32 |   98.1294 |        3.06654 |  0.350231 |  0.297618 |        0.615 |        1.35 |
# | secondary_v2_phase_o2free    | Pyr     |     313 | 1861.1    |        5.94601 | 14.6307   | 11.1364   |       35     |       98    |
# | secondary_v2_phase_o2free    | AcAld   |     193 | 2644.43   |       13.7017  | 29.6127   | 23.5435   |      177     |      288    |
# | secondary_v2_phase_o2free    | Acetate |      50 |  673.245  |       13.4649  |  0.128431 |  0.104563 |        0.3   |        0.39 |
# | secondary_v2_phase_o2free    | O2      |      32 |  188.851  |        5.90159 |  0.485864 |  0.42388  |        0.615 |        1.35 |
# | secondary_v2_phase_o2fixed   | Pyr     |     313 | 2292.76   |        7.3251  | 16.239    | 12.1255   |       35     |       98    |
# | secondary_v2_phase_o2fixed   | AcAld   |     193 | 2685.57   |       13.9148  | 29.8421   | 23.5987   |      177     |      288    |
# | secondary_v2_phase_o2fixed   | Acetate |      50 |  677.581  |       13.5516  |  0.128844 |  0.105026 |        0.3   |        0.39 |
# | secondary_v2_phase_o2fixed   | O2      |      32 |   98.1294 |        3.06654 |  0.350231 |  0.297618 |        0.615 |        1.35 |
# | secondary_v2_reduced_o2fixed | Pyr     |     313 | 2291.95   |        7.32254 | 16.2361   | 12.1285   |       35     |       98    |
# | secondary_v2_reduced_o2fixed | AcAld   |     193 | 2686.89   |       13.9217  | 29.8495   | 23.6152   |      177     |      288    |
# | secondary_v2_reduced_o2fixed | Acetate |      50 |  677.116  |       13.5423  |  0.1288   |  0.10496  |        0.3   |        0.39 |
# | secondary_v2_reduced_o2fixed | O2      |      32 |   98.1294 |        3.06654 |  0.350231 |  0.297618 |        0.615 |        1.35 |
#
# ## v2 weak/confounded parameters
#
# | parameter   |      theta |   std_log_approx |   approx_95_multiplier | active_bound   | classification     |
# |:------------|-----------:|-----------------:|-----------------------:|:---------------|:-------------------|
# | kAldRed     | 1.0183e-05 |          5.07166 |                  20753 | False          | weak_or_confounded |
#
# ## Full v2 estimability
#
# | parameter   |      theta |   std_log_approx |   approx_95_multiplier | active_bound   | classification     |
# |:------------|-----------:|-----------------:|-----------------------:|:---------------|:-------------------|
# | kPyrS_N     | 0.850862   |        0.0379795 |                1.07728 | False          | well_estimated     |
# | kPyrO2      | 0.273189   |        0.100643  |                1.21806 | False          | well_estimated     |
# | kPyrDrain   | 0.00359103 |        0.0604019 |                1.12568 | False          | well_estimated     |
# | kAldS_N     | 2.35989    |        0.0131366 |                1.02608 | False          | well_estimated     |
# | kAldRed     | 1.0183e-05 |        5.07166   |            20753       | False          | weak_or_confounded |
# | kAcAld      | 0.00139231 |        0.0493938 |                1.10165 | False          | well_estimated     |
# | kAcStress   | 0.00261587 |        0.0316527 |                1.064   | False          | well_estimated     |
#
# ## Interpretation
#
# - v2 should be kept only if it improves state-wise errors enough to justify the extra parameters.
# - Parameters that remain weak after v2 should be fixed or strongly regularized before using the model in DOE/MPCC.
# - If v2 improves pyruvate/acetaldehyde but leaves acetate assimilation weak, this supports fixing acetate assimilation rather than forcing DOE to identify it.
